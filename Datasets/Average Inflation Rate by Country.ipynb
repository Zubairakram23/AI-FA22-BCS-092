# %%
import pandas as pd
import numpy as np

BASE_PATH = '/content/drive/MyDrive/Colab Notebooks/economic_indicators_dataset_2010_2023.csv'
# The file path is BASE_PATH. Remove the extra content/Constructor_Performance.csv
driver_details_df = pd.read_csv(BASE_PATH)
driver_details_df.head()
# Out:
#          Date Country  Inflation Rate (%)  GDP Growth Rate (%)  \
# 0  2010-01-31  Brazil                1.23                 0.69
# 1  2010-01-31  France                6.76                 2.59
# 2  2010-01-31     USA                7.46                 4.84
# 3  2010-02-28  Brazil                5.43                 0.31
# 4  2010-02-28  Canada                0.69                -0.52
#
#    Unemployment Rate (%)  Interest Rate (%)  Stock Index Value
# 0                  10.48               7.71           21748.85
# 1                   4.27               7.39           10039.56
# 2                   2.64               6.39           13129.10
# 3                   8.26               6.09           23304.58
# 4                  11.92              -0.51           16413.03

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/economic_indicators_dataset_2010_2023.csv')

# Display basic information about the dataset
df.info()

# Display the first few rows
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   500 non-null    object
#  1   Country                500 non-null    object
#  2   Inflation Rate (%)     500 non-null    float64
#  3   GDP Growth Rate (%)    500 non-null    float64
#  4   Unemployment Rate (%)  500 non-null    float64
#  5   Interest Rate (%)      500 non-null    float64
#  6   Stock Index Value      500 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 27.5+ KB
#          Date Country  Inflation Rate (%)  GDP Growth Rate (%)  \
# 0  2010-01-31  Brazil                1.23                 0.69
# 1  2010-01-31  France                6.76                 2.59
# 2  2010-01-31     USA                7.46                 4.84
# 3  2010-02-28  Brazil                5.43                 0.31
# ...

# %%
print(df.isnull().sum())

# Optionally, you can fill missing values or drop them
df = df.dropna()  # Dropping rows with missing values
# Out:
# Date                     0
# Country                  0
# Inflation Rate (%)       0
# GDP Growth Rate (%)      0
# Unemployment Rate (%)    0
# Interest Rate (%)        0
# Stock Index Value        0
# dtype: int64

# %%
# Summary statistics
df.describe()
# Out:
#        Inflation Rate (%)  GDP Growth Rate (%)  Unemployment Rate (%)  \
# count           500.00000           500.000000             500.000000
# mean              5.08514             2.414780               6.906720
# std               2.95633             4.074762               2.982406
# min               0.00000            -5.000000               2.000000
# 25%               2.52500            -1.170000               4.257500
# 50%               5.20500             2.580000               6.865000
# 75%               7.71000             5.445000               9.502500
# max               9.99000             9.930000              11.970000
#
#        Interest Rate (%)  Stock Index Value
# count         500.000000         500.000000
# mean            4.698180       20926.226540
# std             3.152877       11066.259233
# min            -0.980000        1017.270000
# 25%             2.027500       11587.862500
# 50%             4.975000       20996.210000
# ...

# %%
import plotly.express as px

# Group by Country and calculate the average Inflation Rate
inflation_rate = df.groupby('Country')['Inflation Rate (%)'].mean().reset_index()

# Create a bar plot for Inflation Rate
fig_inflation = px.bar(inflation_rate, x='Country', y='Inflation Rate (%)',
                       title='Average Inflation Rate by Country',
                       labels={'Inflation Rate (%)': 'Inflation Rate (%)'})

fig_inflation.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
race_results_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance.csv') # Changed to the correct file path.
race_results_df.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0     \N
# 1                     2      18              2     8.0     \N
# 2                     3      18              3     9.0     \N
# 3                     4      18              4     5.0     \N
# 4                     5      18              5     2.0     \N

# %%
# Choose the correct DataFrame to use
# driver_details_df.info()
race_results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12505 entries, 0 to 12504
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   constructorResultsId  12505 non-null  int64
#  1   raceId                12505 non-null  int64
#  2   constructorId         12505 non-null  int64
#  3   points                12505 non-null  float64
#  4   status                12505 non-null  object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 488.6+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
constructor_performance = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
constructor_rankings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
driver_details = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
driver_rankings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
lap_timings = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
pit_stop_records = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
qualifying_results = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
race_results = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
race_schedule = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
race_status = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
season_summaries = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
sprint_race_results = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
team_details = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')
track_information = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Constructor_Performance (1).csv')

datasets = {
    'Constructor Performance': constructor_performance,
    'Constructor Rankings': constructor_rankings,
    'Driver Details': driver_details,
    'Driver Rankings': driver_rankings,
    'Lap Timings': lap_timings,
    'Pit Stop Records': pit_stop_records,
    'Qualifying Results': qualifying_results,
    'Race Results': race_results,
    'Race Schedule': race_schedule,
    'Race Status': race_status,
    'Season Summaries': season_summaries,
    'Sprint Race Results': sprint_race_results,
    'Team Details': team_details,
    'Track Information': track_information
}

for name, df in datasets.items():
    print(f"Dataset: {name}")
    print(df.head())
    print(df.info())
    print(df.describe())
    print(df.isnull().sum())
    print("\n")
# Out:
# Dataset: Constructor Performance
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0     \N
# 1                     2      18              2     8.0     \N
# 2                     3      18              3     9.0     \N
# 3                     4      18              4     5.0     \N
# 4                     5      18              5     2.0     \N
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12505 entries, 0 to 12504
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   constructorResultsId  12505 non-null  int64
#  1   raceId                12505 non-null  int64
#  2   constructorId         12505 non-null  int64
#  3   points                12505 non-null  float64
#  4   status                12505 non-null  object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 488.6+ KB
# None
# ...

# %%
plt.figure(figsize=(12, 6))
sns.histplot(constructor_performance['points'], bins=30, kde=True)
plt.title('Distribution of Constructor Points')
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np
import pandas as pd
import os

DATASET_FOLDER = "/content/" # Changed this line
outfits_path = os.path.join(DATASET_FOLDER, "/content/drive/MyDrive/Colab Notebooks/outfits (1).csv") # Changed this line
print(outfits_path)
outfits_df = pd.read_csv(outfits_path, sep=";")

# CSV files are read as strings, so we need to convert them to lists
outfits_df["tag_categories"] = outfits_df["tag_categories"].apply(eval)
outfits_df["outfit_tags"] = outfits_df["outfit_tags"].apply(eval)

outfits_df.head(3)
# Out:
# /content/drive/MyDrive/Colab Notebooks/outfits (1).csv
#                                         id  \
# 0  outfit.fffdaa715c3646f8b1c0f04d549ff07e
# 1  outfit.fffa1b9a3db6415d806f3c48f8ab58d9
# 2  outfit.fff175b13ceb453f9928625491412ede
#
#                                       name  \
# 0  Out of stock - Asymmetric Frilled Dress
# 1        Yellow Shell Mellomholmene Blouse
# 2                        Kaula Dress Black
#
#                                          description  \
# 0  This fun, short dress features and asymmetric ...
# 1  This beautiful blouse features an adjustable n...
# 2  Kaula from Rodebjer is a fitted dress made in ...
#
#                                     group  owner              timeCreated  \
# 0  group.50a586c78eb7626e294ba3bd07d12c79    217  2017-12-30 11:28:01.000
# 1  group.61ad2fcabb3e9197e3836376e6b67f2c    214  2021-06-07 12:07:22.921
# 2  group.37c2b59d63d3a9c2d58e07f532f71f7f    341  2023-06-05 09:17:59.004
#
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/economic_indicators_dataset_2010_2023.csv')

# Display basic information about the dataset
df.info()

# Display the first few rows
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   500 non-null    object
#  1   Country                500 non-null    object
#  2   Inflation Rate (%)     500 non-null    float64
#  3   GDP Growth Rate (%)    500 non-null    float64
#  4   Unemployment Rate (%)  500 non-null    float64
#  5   Interest Rate (%)      500 non-null    float64
#  6   Stock Index Value      500 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 27.5+ KB
#          Date Country  Inflation Rate (%)  GDP Growth Rate (%)  \
# 0  2010-01-31  Brazil                1.23                 0.69
# 1  2010-01-31  France                6.76                 2.59
# 2  2010-01-31     USA                7.46                 4.84
# 3  2010-02-28  Brazil                5.43                 0.31
# ...

# %%
# Check for missing values
print(df.isnull().sum())

# Optionally, you can fill missing values or drop them
df = df.dropna()  # Dropping rows with missing values
# Out:
# Date                     0
# Country                  0
# Inflation Rate (%)       0
# GDP Growth Rate (%)      0
# Unemployment Rate (%)    0
# Interest Rate (%)        0
# Stock Index Value        0
# dtype: int64

# %%
# Summary statistics
df.describe()
# Out:
#        Inflation Rate (%)  GDP Growth Rate (%)  Unemployment Rate (%)  \
# count           500.00000           500.000000             500.000000
# mean              5.08514             2.414780               6.906720
# std               2.95633             4.074762               2.982406
# min               0.00000            -5.000000               2.000000
# 25%               2.52500            -1.170000               4.257500
# 50%               5.20500             2.580000               6.865000
# 75%               7.71000             5.445000               9.502500
# max               9.99000             9.930000              11.970000
#
#        Interest Rate (%)  Stock Index Value
# count         500.000000         500.000000
# mean            4.698180       20926.226540
# std             3.152877       11066.259233
# min            -0.980000        1017.270000
# 25%             2.027500       11587.862500
# 50%             4.975000       20996.210000
# ...

# %%
import plotly.express as px

# Group by Country and calculate the average Inflation Rate
inflation_rate = df.groupby('Country')['Inflation Rate (%)'].mean().reset_index()

# Create a bar plot for Inflation Rate
fig_inflation = px.bar(inflation_rate, x='Country', y='Inflation Rate (%)',
                       title='Average Inflation Rate by Country',
                       labels={'Inflation Rate (%)': 'Inflation Rate (%)'})

fig_inflation.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
gdp_growth = df.groupby('Country')['GDP Growth Rate (%)'].mean().reset_index()

# Create a bar plot for GDP Growth Rate
fig_gdp = px.bar(gdp_growth, x='Country', y='GDP Growth Rate (%)',
                 title='Average GDP Growth Rate by Country',
                 labels={'GDP Growth Rate (%)': 'GDP Growth Rate (%)'})

fig_gdp.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
student_data=pd.read_csv('/content/sample_data/StudentsPerformance.csv')
student_data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
student_data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
student_data['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
student_data['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
student_data['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
student_data['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
student_data['test preparation course'].value_counts()
# Out:
# test preparation course
# none         642
# completed    358
# Name: count, dtype: int64

# %%
student_data['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
student_data['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)
